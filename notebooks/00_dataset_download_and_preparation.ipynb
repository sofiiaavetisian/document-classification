# %% [markdown]
# # Dataset Download and Preparation
# This notebook calls the reproducible script to build the 5-class subset :
#
# (`invoice`, `form`, `resume`, `email`, `budget`) and train/val/test splits

# %%
from pathlib import Path
PROJECT_ROOT = Path('..').resolve()
PROJECT_ROOT
# Out:
# PosixPath('/Users/sofiiaavetisian/Desktop/UNI/statistical_learning/FINAL_PROJECT/document-classification/document_classification_project')

# %% [markdown]
# # Download from Kaggle using the script

# %%
cmd = f"python {PROJECT_ROOT / 'scripts' / 'prepare_five_class_dataset.py'} --project-root {PROJECT_ROOT} --download --copy-mode symlink --compute-hash"
print(cmd)
# Out:
# python /Users/sofiiaavetisian/Desktop/UNI/statistical_learning/FINAL_PROJECT/document-classification/document_classification_project/scripts/prepare_five_class_dataset.py --project-root /Users/sofiiaavetisian/Desktop/UNI/statistical_learning/FINAL_PROJECT/document-classification/document_classification_project --download --copy-mode symlink --compute-hash

# %% [markdown]
# # Dataset location
#
# The dataset with the 5 classes and the train/val/test split:
#
# - `document-classification/data/processed/five_class_subset`
